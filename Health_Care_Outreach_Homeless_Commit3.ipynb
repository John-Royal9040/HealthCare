# %%
#Just Want to Confirm Libraries Are In

# %% [markdown]
# Revised Research Question

# %% [markdown]
# How does education, income levels, and awareness impact the utilization of Medicaid and other healthcare benefits among individuals in urban areas, specifically homeless population in Baltimore,Maryland, who have access to these resources? Additionally, what factors contribute to the underutilization of available healthcare programs despite their accessibility?

# %% [markdown]
# Purpose Statement

# %% [markdown]
# The purpose of this study is to analyze the impact of education, income levels, and awareness on the utilization of Medicaid and other healthcare benefits among individuals residing in urban areas with access to these resources. By examining patterns of benefit usage, this research seeks to identify key factors that influence enrollment and participation in available healthcare programs. Additionally, this study aims to explore the reasons behind the underutilization of these programs despite their accessibility with comparissons to homeless populations within Baltimore, Maryland. Understanding these dynamics will provide valuable insights for policymakers, healthcare providers, and community organizations to improve outreach, education, and program effectiveness, ultimately enhancing healthcare equity and accessibility.

# %%
#Example Data Set

# %% [markdown]
# This data set includes annual counts and percentages of Medicaid and Children’s Health Insurance Program (CHIP) enrollees by race and ethnicity overall and by three subpopulation topics: scope of Medicaid and CHIP benefits, age group, and eligibility category. Also breaks it out geographically within the US, it was last updated January 16,2025. https://data.medicaid.gov/dataset/b9e18d80-c765-4fb9-95e7-81951e01a6a3#overview

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# Import Pandas library

# %%
import pandas as pd

# %%
import os
print(os.getcwd())  # Show the current working directory
print(os.listdir())  # List files in the current directory
# Out:
# /Users/johnroyal/Python
# ['SetUp.ipynb', 'race-and-ethnicity-2020-2022-01162025.csv', 'Health_Care_Outreach_Homeless.ipynb', '.ipynb_checkpoints']

# %%
# Get the current directory
current_directory = os.getcwd()

# Define the full file path
file_path = os.path.join(current_directory, "'/Users/johnroyal/Documents/race-and-ethnicity-2020-2022-01162025 (2).csv'")

# %%
Health_Care_Medicaid_Race_Ethnicty = pd.read_csv('/Users/johnroyal/Documents/race-and-ethnicity-2020-2022-01162025 (2).csv')

# %%
#Changing Column Names
Health_Care_Medicaid_Race_Ethnicty.columns = ["Year", "Geography", "MUCBU","Life Stage/Defined","Race","Enrollees","Denominator","Percentage","Version"]

# %%
print(Health_Care_Medicaid_Race_Ethnicty.columns)
# Out:
# Index(['Year', 'Geography', 'MUCBU', 'Life Stage/Defined', 'Race', 'Enrollees',
#        'Denominator', 'Percentage', 'Version'],
#       dtype='object')

# %%
Health_Care_Medicaid_Race_Ethnicty.head(7)
# Out:
#    Year Geography      MUCBU Life Stage/Defined  \
# 0  2020  National  Age group              Adult
# 1  2020  National  Age group              Adult
# 2  2020  National  Age group              Adult
# 3  2020  National  Age group              Adult
# 4  2020  National  Age group              Adult
# 5  2020  National  Age group              Adult
# 6  2020  National  Age group              Child
#
#                                               Race   Enrollees Denominator  \
# 0  American Indian and Alaska Native, non-Hispanic     653,439  47,168,817
# 1             Asian/Pacific Islander, non-Hispanic   3,258,628  47,168,817
# 2                              Black, non-Hispanic   9,592,152  47,168,817
# 3                                         Hispanic  10,955,420  47,168,817
# 4                        Multiracial, non-Hispanic     485,996  47,168,817
# 5                              White, non-Hispanic  22,223,182  47,168,817
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.tail(7)
# Out:
#      Year Geography                 MUCBU           Life Stage/Defined  \
# 209  2022  National  Eligibility category                    Pregnancy
# 210  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 211  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 212  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 213  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 214  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 215  2022  National       Total enrollees  Medicaid and CHIP enrollees
#
#                                                 Race   Enrollees  Denominator  \
# 209                              White, non-Hispanic     812,619   42,466,493
# 210  American Indian and Alaska Native, non-Hispanic   1,389,475  108,871,502
# 211             Asian/Pacific Islander, non-Hispanic   6,063,432  108,871,502
# 212                              Black, non-Hispanic  22,438,791  108,871,502
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.info #Backup Method 'cause I need all these points
# Out:
# <bound method DataFrame.info of      Year Geography            MUCBU           Life Stage/Defined  \
# 0    2020  National        Age group                        Adult
# 1    2020  National        Age group                        Adult
# 2    2020  National        Age group                        Adult
# 3    2020  National        Age group                        Adult
# 4    2020  National        Age group                        Adult
# ..    ...       ...              ...                          ...
# 211  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 212  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 213  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 214  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 215  2022  National  Total enrollees  Medicaid and CHIP enrollees
#
#                                                 Race   Enrollees  Denominator  \
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.shape # Rows and columns
Health_Care_Medicaid_Race_Ethnicty.info # Data types & missing values
# Out:
# <bound method DataFrame.info of      Year Geography            MUCBU           Life Stage/Defined  \
# 0    2020  National        Age group                        Adult
# 1    2020  National        Age group                        Adult
# 2    2020  National        Age group                        Adult
# 3    2020  National        Age group                        Adult
# 4    2020  National        Age group                        Adult
# ..    ...       ...              ...                          ...
# 211  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 212  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 213  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 214  2022  National  Total enrollees  Medicaid and CHIP enrollees
# 215  2022  National  Total enrollees  Medicaid and CHIP enrollees
#
#                                                 Race   Enrollees  Denominator  \
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.isnull().sum()
# Out:
# Year                  0
# Geography             0
# MUCBU                 0
# Life Stage/Defined    0
# Race                  0
# Enrollees             0
# Denominator           0
# Percentage            0
# Version               0
# dtype: int64

# %%
Health_Care_Medicaid_Race_Ethnicty.dropna(inplace=True)

# %%
#Noticed Didn't Have Null Values Cause I Pick the Bestest of Datasets - Creating Null Values 2 Birds

# %%
Health_Care_Medicaid_Race_Ethnicty.head(7)
# Out:
#    Year Geography      MUCBU Life Stage/Defined  \
# 0  2020  National  Age group              Adult
# 1  2020  National  Age group              Adult
# 2  2020  National  Age group              Adult
# 3  2020  National  Age group              Adult
# 4  2020  National  Age group              Adult
# 5  2020  National  Age group              Adult
# 6  2020  National  Age group              Child
#
#                                               Race   Enrollees Denominator  \
# 0  American Indian and Alaska Native, non-Hispanic     653,439  47,168,817
# 1             Asian/Pacific Islander, non-Hispanic   3,258,628  47,168,817
# 2                              Black, non-Hispanic   9,592,152  47,168,817
# 3                                         Hispanic  10,955,420  47,168,817
# 4                        Multiracial, non-Hispanic     485,996  47,168,817
# 5                              White, non-Hispanic  22,223,182  47,168,817
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.tail(7)
# Out:
#      Year Geography                 MUCBU           Life Stage/Defined  \
# 209  2022  National  Eligibility category                    Pregnancy
# 210  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 211  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 212  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 213  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 214  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 215  2022  National       Total enrollees  Medicaid and CHIP enrollees
#
#                                                 Race   Enrollees  Denominator  \
# 209                              White, non-Hispanic     812,619   42,466,493
# 210  American Indian and Alaska Native, non-Hispanic   1,389,475  108,871,502
# 211             Asian/Pacific Islander, non-Hispanic   6,063,432  108,871,502
# 212                              Black, non-Hispanic  22,438,791  108,871,502
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.isnull().any() #Bruh...
# Out:
# Year                  False
# Geography             False
# MUCBU                 False
# Life Stage/Defined    False
# Race                  False
# Enrollees             False
# Denominator           False
# Percentage            False
# Version               False
# New_Column            False
# Example_Column        False
# dtype: bool

# %%
Health_Care_Medicaid_Race_Ethnicty['Third_Fake_Column'] = None

# %%
Health_Care_Medicaid_Race_Ethnicty.isnull().any() #So I goofed twice by adding Np.Nan technically it was a value
# Out:
# Year                  False
# Geography             False
# MUCBU                 False
# Life Stage/Defined    False
# Race                  False
# Enrollees             False
# Denominator           False
# Percentage            False
# Version               False
# New_Column            False
# Example_Column        False
# Third_Fake_Column      True
# dtype: bool

# %%
#Rubric States You Need Count so adding here
Health_Care_Medicaid_Race_Ethnicty.isnull().sum()
# Out:
# Year                    0
# Geography               0
# MUCBU                   0
# Life Stage/Defined      0
# Race                    0
# Enrollees               0
# Denominator             0
# Percentage              0
# Version                 0
# New_Column              0
# Example_Column          0
# Third_Fake_Column     216
# dtype: int64

# %%
Health_Care_Medicaid_Race_Ethnicty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                216 non-null    int64
#  1   Geography           216 non-null    object
#  2   MUCBU               216 non-null    object
#  3   Life Stage/Defined  216 non-null    object
#  4   Race                216 non-null    object
#  5   Enrollees           216 non-null    object
#  6   Denominator         216 non-null    object
#  7   Percentage          216 non-null    float64
#  8   Version             216 non-null    object
#  9   New_Column          216 non-null    object
#  10  Example_Column      216 non-null    object
#  11  Third_Fake_Column   0 non-null      object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 20.4+ KB

# %%
#Dropping Un-Needed Columns - Keeping One with Nulls
Health_Care_Medicaid_Race_Ethnicty.drop(columns=['New_Column','Example_Column'], inplace=True)

# %%
Health_Care_Medicaid_Race_Ethnicty.head(7)
# Out:
#    Year Geography      MUCBU Life Stage/Defined  \
# 0  2020  National  Age group              Adult
# 1  2020  National  Age group              Adult
# 2  2020  National  Age group              Adult
# 3  2020  National  Age group              Adult
# 4  2020  National  Age group              Adult
# 5  2020  National  Age group              Adult
# 6  2020  National  Age group              Child
#
#                                               Race   Enrollees Denominator  \
# 0  American Indian and Alaska Native, non-Hispanic     653,439  47,168,817
# 1             Asian/Pacific Islander, non-Hispanic   3,258,628  47,168,817
# 2                              Black, non-Hispanic   9,592,152  47,168,817
# 3                                         Hispanic  10,955,420  47,168,817
# 4                        Multiracial, non-Hispanic     485,996  47,168,817
# 5                              White, non-Hispanic  22,223,182  47,168,817
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.tail(7)
# Out:
#      Year Geography                 MUCBU           Life Stage/Defined  \
# 209  2022  National  Eligibility category                    Pregnancy
# 210  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 211  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 212  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 213  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 214  2022  National       Total enrollees  Medicaid and CHIP enrollees
# 215  2022  National       Total enrollees  Medicaid and CHIP enrollees
#
#                                                 Race   Enrollees  Denominator  \
# 209                              White, non-Hispanic     812,619   42,466,493
# 210  American Indian and Alaska Native, non-Hispanic   1,389,475  108,871,502
# 211             Asian/Pacific Islander, non-Hispanic   6,063,432  108,871,502
# 212                              Black, non-Hispanic  22,438,791  108,871,502
# ...

# %%
Health_Care_Medicaid_Race_Ethnicty.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                216 non-null    int64
#  1   Geography           216 non-null    object
#  2   MUCBU               216 non-null    object
#  3   Life Stage/Defined  216 non-null    object
#  4   Race                216 non-null    object
#  5   Enrollees           216 non-null    object
#  6   Denominator         216 non-null    object
#  7   Percentage          216 non-null    float64
#  8   Version             216 non-null    object
#  9   Third_Fake_Column   0 non-null      object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 17.0+ KB

# %%
Health_Care_Medicaid_Race_Ethnicty.shape
# Out:
# (216, 10)

# %%
# Get the number of rows and columns
rows, columns = df.shape
total_data_points = rows * columns

# %%
print("Total number of data points:", total_data_points)
# Out:
# Total number of data points: 1944
